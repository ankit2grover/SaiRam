# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1/)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'as', 'of', 'originated', 'term']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.058521
# Nearest to can: spasms, clauses, messianic, racer, gto, menlo, exmoor, friction,
# Nearest to over: angola, cs, rationalistic, innocuous, triangle, sasl, montferrat, azteca,
# Nearest to may: mindedness, dogmatically, rbis, oceanographer, enders, fm, argumentation, pye,
# Nearest to while: singleton, fiske, epsilon, parabola, invoked, lepers, expansion, clerical,
# Nearest to state: eubulides, mosaic, nijmegen, savannah, zeta, ordination, resurgent, ericaceae,
# Nearest to about: gotha, precipitating, ek, fuel, montana, analysts, cluster, lucien,
# Nearest to known: riso, delivery, lifespan, dogs, heavenly, harriers, formalism, communions,
# Nearest to which: lubricating, animators, playlist, cipher, kaiser, lemnos, kiln, introduce,
# Nearest to but: hideout, immigrants, gymnasium, bundaberg, fw, girlfriends, malley, cavitation,
# Nearest to it: riemannian, infibulation, abrams, felix, spectacularly, tragedies, delian, atoms,
# Nearest to new: anytime, palermo, dwight, rpg, regards, crediting, slabs, batting,
# Nearest to his: nellis, phi, holocene, mikvah, depressant, harbin, stomachs, ostensible,
# Nearest to zero: mystery, directional, prescient, michael, graf, fincher, allergic, christe,
# Nearest to called: wtc, fhm, eclipsing, wickedness, cassava, verbatim, stokes, devoting,
# Nearest to who: tomb, hee, false, ginette, zimbabwe, positioning, genie, forgetful,
# Nearest to first: subsonic, cultivar, permutation, naturalized, histone, tld, nitro, kitzmiller,
# Average loss at step 2000: 4.359540
# Average loss at step 4000: 3.865348
# Average loss at step 6000: 3.787236
# Average loss at step 8000: 3.685371
# Average loss at step 10000: 3.615082
# Nearest to can: would, could, may, clauses, might, spasms, lepidus, messianic,
# Nearest to over: gall, visceral, affidavit, rationalistic, angola, delegation, dredging, importing,
# Nearest to may: can, could, might, would, mindedness, indignation, arno, angra,
# Nearest to while: after, singleton, fiske, noa, esk, cueing, parabola, argentinean,
# Nearest to state: mosaic, joab, applying, teaspoon, savannah, eubulides, padua, abodes,
# Nearest to about: cluster, falkirk, gluten, keith, torment, correspondance, no, analysts,
# Nearest to known: riso, lifespan, prophesies, encapsulated, subgroups, heavenly, delivery, seminar,
# Nearest to which: that, it, colt, overruns, mischievous, malfunctions, this, lemnos,
# Nearest to but: immigrants, hideout, nitrous, retook, brands, participated, lebesgue, called,
# Nearest to it: he, this, there, which, not, she, they, often,
# Nearest to new: anytime, dwight, rebuild, cedric, bissau, complicates, staggering, sealing,
# Nearest to his: their, her, the, s, its, this, orchids, gatsby,
# Nearest to zero: five, seven, six, nine, eight, three, four, two,
# Nearest to called: cassava, wtc, wickedness, fhm, tangle, naturalism, stokes, eclipsing,
# Nearest to who: he, they, documents, and, usually, ellipses, positioning, universally,
# Nearest to first: defiant, during, module, same, vanities, beautifully, subvert, sturdy,
# Average loss at step 12000: 3.606553
# Average loss at step 14000: 3.566270
# Average loss at step 16000: 3.409410
# Average loss at step 18000: 3.460408
# Average loss at step 20000: 3.543292
# Nearest to can: may, would, could, will, should, might, to, must,
# Nearest to over: gall, visceral, delegation, hammersmith, irritated, haag, affidavit, azteca,
# Nearest to may: can, would, might, could, must, chee, should, to,
# Nearest to while: after, fiske, noa, headstock, fragrance, parabola, when, singleton,
# Nearest to state: joab, mosaic, eubulides, padua, teaspoon, accuses, applying, litigants,
# Nearest to about: consigned, keith, receptive, torment, analysts, harvesting, vegan, taganrog,
# Nearest to known: such, defined, used, prophesies, reagent, subgroups, teams, hira,
# Nearest to which: that, this, overruns, it, who, but, also, still,
# Nearest to but: and, however, which, that, is, was, if, monotonicity,
# Nearest to it: he, this, there, they, she, which, kets, not,
# Nearest to new: complicates, dwight, anytime, jornal, historia, staggering, rebuild, response,
# Nearest to his: their, her, its, the, fiercely, foundationalism, taiko, webern,
# Nearest to zero: five, seven, six, eight, three, four, nine, two,
# Nearest to called: cassava, wtc, patrimony, naturalism, wickedness, newt, eclipsing, traced,
# Nearest to who: he, which, also, they, usually, often, genie, natal,
# Nearest to first: next, vice, same, past, subvert, kristin, during, exact,
# Average loss at step 22000: 3.502925
# Average loss at step 24000: 3.489892
# Average loss at step 26000: 3.486749
# Average loss at step 28000: 3.479330
# Average loss at step 30000: 3.499210
# Nearest to can: could, would, may, will, might, should, must, cannot,
# Nearest to over: gall, visceral, delegation, hammersmith, affidavit, abc, irritated, ventricle,
# Nearest to may: can, would, might, could, must, will, should, cannot,
# Nearest to while: after, but, although, fiske, where, metadata, headstock, when,
# Nearest to state: joab, mosaic, eubulides, teaspoon, padua, applying, fragile, states,
# Nearest to about: taganrog, centred, receptive, biomedical, harvesting, clung, between, mostar,
# Nearest to known: used, such, defined, reagent, well, hira, seen, possible,
# Nearest to which: that, this, overruns, what, who, there, it, but,
# Nearest to but: however, although, and, or, nor, when, while, encloses,
# Nearest to it: he, there, she, this, they, kets, which, only,
# Nearest to new: dwight, complicates, geography, gygax, jornal, turkish, vasili, ta,
# Nearest to his: their, her, its, the, s, my, this, elven,
# Nearest to zero: five, eight, nine, four, seven, six, three, two,
# Nearest to called: cassava, wtc, patrimony, sprache, newt, competes, traced, wickedness,
# Nearest to who: he, which, they, also, already, and, usually, never,
# Nearest to first: second, same, next, baloch, vice, exact, during, defiant,
# Average loss at step 32000: 3.503615
# Average loss at step 34000: 3.494965
# Average loss at step 36000: 3.451327
# Average loss at step 38000: 3.300324
# Average loss at step 40000: 3.429253
# Nearest to can: could, may, will, would, must, might, should, cannot,
# Nearest to over: gall, visceral, into, haag, irritated, ventricle, hydrofoil, chronology,
# Nearest to may: can, would, will, could, might, must, should, cannot,
# Nearest to while: although, after, but, when, farther, where, though, however,
# Nearest to state: joab, government, teaspoon, applying, accuses, states, beginnings, litigants,
# Nearest to about: mostar, taganrog, napkin, harvesting, clung, kapital, vividly, pandora,
# Nearest to known: used, such, defined, possible, regarded, reagent, well, considered,
# Nearest to which: that, this, who, usually, also, overruns, what, often,
# Nearest to but: however, and, although, while, nor, though, which, soyuz,
# Nearest to it: he, there, she, they, this, actually, then, not,
# Nearest to new: dwight, batting, complicates, geography, outstanding, boomerang, atkins, gygax,
# Nearest to his: their, her, its, s, my, the, foundationalism, readily,
# Nearest to zero: seven, five, eight, nine, six, three, four, two,
# Nearest to called: cassava, traced, wickedness, sprache, wtc, crusoe, schiff, patrimony,
# Nearest to who: which, he, often, usually, also, that, they, already,
# Nearest to first: second, next, last, same, illyria, vice, origination, stevens,
# Average loss at step 42000: 3.431440
# Average loss at step 44000: 3.451513
# Average loss at step 46000: 3.450477
# Average loss at step 48000: 3.346401
# Average loss at step 50000: 3.380347
# Nearest to can: may, could, will, would, must, might, should, cannot,
# Nearest to over: gall, into, visceral, clarkson, longship, through, chronology, greatest,
# Nearest to may: can, would, will, might, could, should, must, cannot,
# Nearest to while: after, although, when, where, however, eugenicists, but, before,
# Nearest to state: joab, teaspoon, states, litigants, fontana, applying, government, beginnings,
# Nearest to about: harvesting, mostar, napkin, transfered, clung, kapital, biomedical, enthalpy,
# Nearest to known: used, such, defined, regarded, possible, seen, well, preserved,
# Nearest to which: that, this, who, also, what, overruns, usually, but,
# Nearest to but: however, although, and, though, when, which, that, while,
# Nearest to it: he, there, she, this, they, which, often, torpedo,
# Nearest to new: gygax, batting, complicates, ta, atkins, priceless, mosiah, victorians,
# Nearest to his: their, her, its, my, the, whose, stylistically, your,
# Nearest to zero: five, seven, three, four, eight, six, two, nine,
# Nearest to called: cassava, named, wtc, competes, traced, patrimony, qualification, corresponded,
# Nearest to who: which, he, she, also, often, they, generally, usually,
# Nearest to first: last, next, second, same, zhu, only, illyria, exact,
# Average loss at step 52000: 3.435257
# Average loss at step 54000: 3.430610
# Average loss at step 56000: 3.437694
# Average loss at step 58000: 3.398797
# Average loss at step 60000: 3.392428
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to over: gall, through, around, into, visceral, throughout, longship, delegation,
# Nearest to may: can, would, might, will, could, should, must, cannot,
# Nearest to while: although, after, when, before, though, eugenicists, where, if,
# Nearest to state: joab, applying, government, states, accuses, reform, teaspoon, puzzles,
# Nearest to about: around, harvesting, regarding, transfered, over, replicates, mostar, vividly,
# Nearest to known: used, such, regarded, defined, possible, seen, important, favours,
# Nearest to which: that, this, what, it, overruns, who, but, however,
# Nearest to but: however, although, and, though, which, see, or, when,
# Nearest to it: he, this, she, there, which, they, what, that,
# Nearest to new: gygax, complicates, batting, geography, response, priceless, proactive, incidence,
# Nearest to his: her, their, its, my, whose, stylistically, the, your,
# Nearest to zero: five, seven, eight, four, six, nine, three, two,
# Nearest to called: cassava, used, wtc, competes, traced, reviews, known, allophones,
# Nearest to who: he, which, generally, never, usually, she, still, now,
# Nearest to first: last, second, next, same, past, exact, originally, only,
# Average loss at step 62000: 3.240156
# Average loss at step 64000: 3.253285
# Average loss at step 66000: 3.401693
# Average loss at step 68000: 3.390797
# Average loss at step 70000: 3.358100
# Nearest to can: may, could, will, would, might, must, cannot, should,
# Nearest to over: about, into, through, throughout, gall, around, nyasa, delegation,
# Nearest to may: can, will, might, could, would, should, must, cannot,
# Nearest to while: although, after, before, though, when, however, where, including,
# Nearest to state: government, joab, city, states, teaspoon, regrettable, applying, accuses,
# Nearest to about: regarding, around, over, vividly, mostar, biomedical, replicates, micron,
# Nearest to known: used, such, defined, regarded, seen, well, possible, considered,
# Nearest to which: that, this, what, also, but, usually, it, however,
# Nearest to but: however, although, that, and, though, which, while, or,
# Nearest to it: he, she, there, this, they, usually, still, then,
# Nearest to new: gygax, complicates, worthies, priceless, response, artefact, bradman, batting,
# Nearest to his: her, their, my, its, whose, stylistically, your, portray,
# Nearest to zero: six, eight, five, four, seven, nine, three, two,
# Nearest to called: named, competes, wtc, reviews, known, cassava, used, rohmer,
# Nearest to who: he, generally, which, she, uniformly, they, often, usually,
# Nearest to first: last, second, next, same, past, third, final, exact,
# Average loss at step 72000: 3.370864
# Average loss at step 74000: 3.350488
# Average loss at step 76000: 3.308945
# Average loss at step 78000: 3.347513
# Average loss at step 80000: 3.378549
# Nearest to can: could, will, may, must, would, cannot, should, might,
# Nearest to over: around, into, throughout, between, through, about, fullerenes, within,
# Nearest to may: could, will, can, might, would, should, must, cannot,
# Nearest to while: although, after, though, when, before, however, but, eugenicists,
# Nearest to state: government, vanderbilt, city, states, joab, press, amanda, adjacent,
# Nearest to about: around, approximately, vividly, over, regarding, micron, transfered, maccabees,
# Nearest to known: used, defined, regarded, such, seen, referred, possible, considered,
# Nearest to which: that, this, what, norodom, usually, gabal, also, often,
# Nearest to but: however, although, and, though, while, glider, or, see,
# Nearest to it: he, she, there, this, they, never, itself, not,
# Nearest to new: worthies, batting, bastard, miyamoto, publishers, single, jornal, response,
# Nearest to his: her, their, my, its, your, the, our, stylistically,
# Nearest to zero: seven, five, six, eight, four, three, nine, two,
# Nearest to called: named, known, referred, competes, wtc, see, allophones, kuiper,
# Nearest to who: he, she, usually, they, generally, often, never, which,
# Nearest to first: last, second, next, same, third, final, stationary, zhu,
# Average loss at step 82000: 3.405968
# Average loss at step 84000: 3.408743
# Average loss at step 86000: 3.388760
# Average loss at step 88000: 3.349991
# Average loss at step 90000: 3.365052
# Nearest to can: could, may, will, must, would, might, should, cannot,
# Nearest to over: around, through, into, nyasa, throughout, within, off, further,
# Nearest to may: can, could, might, should, would, will, must, cannot,
# Nearest to while: although, though, when, after, before, but, during, however,
# Nearest to state: government, city, joab, vanderbilt, amanda, states, inception, accuses,
# Nearest to about: regarding, around, vividly, concerning, over, approximately, maccabees, micron,
# Nearest to known: used, such, defined, regarded, seen, possible, called, referred,
# Nearest to which: that, this, what, usually, also, but, it, both,
# Nearest to but: however, and, although, though, that, while, which, he,
# Nearest to it: he, she, this, there, itself, they, katsura, we,
# Nearest to new: worthies, response, separate, thyroxine, different, bradman, jornal, localization,
# Nearest to his: her, their, its, my, your, the, whose, s,
# Nearest to zero: five, seven, eight, six, nine, four, three, two,
# Nearest to called: known, referred, named, competes, cassava, allophones, wtc, used,
# Nearest to who: he, often, she, also, generally, which, never, already,
# Nearest to first: last, second, next, same, original, stationary, third, final,
# Average loss at step 92000: 3.396531
# Average loss at step 94000: 3.255171
# Average loss at step 96000: 3.353114
# Average loss at step 98000: 3.244456
# Average loss at step 100000: 3.356519
# Nearest to can: could, may, must, will, would, should, might, cannot,
# Nearest to over: around, fullerenes, into, within, through, nyasa, throughout, towards,
# Nearest to may: can, could, might, should, would, must, will, cannot,
# Nearest to while: although, when, though, after, before, but, where, and,
# Nearest to state: city, government, vanderbilt, press, states, amanda, stirrup, riviera,
# Nearest to about: regarding, around, approximately, vividly, clung, on, harvesting, thiele,
# Nearest to known: used, such, defined, possible, seen, regarded, called, referred,
# Nearest to which: that, this, usually, what, these, who, but, based,
# Nearest to but: however, and, although, though, while, kojiki, which, did,
# Nearest to it: he, she, this, they, there, never, what, itself,
# Nearest to new: separate, different, gygax, worthies, response, bradman, thyroxine, bastard,
# Nearest to his: her, their, my, its, your, the, s, our,
# Nearest to zero: five, four, eight, seven, six, nine, three, two,
# Nearest to called: named, referred, known, cassava, competes, wtc, allophones, used,
# Nearest to who: he, she, never, which, still, now, generally, often,
# Nearest to first: last, next, second, third, fourteenth, final, same, kingship,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

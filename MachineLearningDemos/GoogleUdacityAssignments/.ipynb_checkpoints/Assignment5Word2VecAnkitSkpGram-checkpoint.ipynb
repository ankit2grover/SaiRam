# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'as', 'term', 'of', 'originated']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.843048
# Nearest to he: grasping, masefield, dolmen, porte, knockout, hull, widely, rho,
# Nearest to an: bedding, repainted, madly, southerly, quorum, cryonicists, osi, dd,
# Nearest to other: torpedo, dissociate, sociologist, cadiz, ghali, assert, look, neurotoxicity,
# Nearest to zero: biqa, process, yeomen, subset, cmu, ineffable, chs, pairwise,
# Nearest to history: hostname, imposes, yakko, mitre, equip, reymond, barricade, ordinals,
# Nearest to most: elemental, proclamations, hast, found, synonymous, screenshot, strength, tusks,
# Nearest to four: hon, flowing, signing, ilp, older, sax, scarab, farrar,
# Nearest to i: exclusivity, tallies, levy, nubcake, telephone, debtors, janos, respectability,
# Nearest to to: iud, factorial, barbed, kansai, smashing, elfman, highbury, fearsome,
# Nearest to of: masque, abd, circumcisions, deseret, medians, ser, kenning, morgue,
# Nearest to also: veitch, pipers, adolescence, incited, braking, bilaterally, embarrassing, waived,
# Nearest to his: gallagher, disseminate, resided, informers, aberrations, milky, anyone, afternoon,
# Nearest to can: hieroglyph, dissected, chimpanzee, tying, feasting, wmap, geer, fancy,
# Nearest to if: defenseless, ratings, dreadnoughts, claudio, sadd, hyperion, bihari, scofield,
# Nearest to was: rgya, ismail, anastasia, everest, persist, bled, aluminium, cuff,
# Nearest to after: hearth, vehemently, digraphs, subconscious, djvu, justify, denouncing, fierce,
# Average loss at step 2000: 4.363900
# Average loss at step 4000: 3.861923
# Average loss at step 6000: 3.789062
# Average loss at step 8000: 3.686338
# Average loss at step 10000: 3.611668
# Nearest to he: it, she, they, who, there, brp, guessing, you,
# Nearest to an: meticulously, the, cryonicists, ludvig, discounted, golgi, southerly, respects,
# Nearest to other: aspirant, player, cadiz, neurotoxicity, regional, japanese, sickle, athena,
# Nearest to zero: five, nine, seven, eight, six, four, three, two,
# Nearest to history: ordinals, alexey, percent, libby, disengage, drug, flax, mitre,
# Nearest to most: some, relinquished, elemental, hast, metastasis, measure, myles, laity,
# Nearest to four: six, eight, seven, five, three, nine, two, zero,
# Nearest to i: exclusivity, rhetorical, tolerated, you, francisco, chisel, nubcake, dorians,
# Nearest to to: not, would, iud, paullus, nie, pivot, can, refusal,
# Nearest to of: in, tricky, for, vientiane, valiantly, gladiators, brahui, abd,
# Nearest to also: which, tlp, microclimates, it, adolescence, vuoksi, paladin, been,
# Nearest to his: their, her, the, its, s, posner, this, any,
# Nearest to can: would, may, will, must, should, could, commemorated, instantaneous,
# Nearest to if: defenseless, since, sadd, is, hustle, ratings, shower, comments,
# Nearest to was: is, had, has, were, are, by, been, be,
# Nearest to after: hhs, wants, lyle, lord, merging, coordinators, sampras, clive,
# Average loss at step 12000: 3.606179
# Average loss at step 14000: 3.573831
# Average loss at step 16000: 3.411498
# Average loss at step 18000: 3.457083
# Average loss at step 20000: 3.541609
# Nearest to he: it, she, they, who, there, lifting, we, devaluation,
# Nearest to an: cryonicists, crops, polisario, meticulously, discounted, huron, zyklon, imre,
# Nearest to other: these, many, regional, religious, some, such, aspirant, whitacre,
# Nearest to zero: five, four, six, three, seven, eight, nine, two,
# Nearest to history: ordinals, libby, percent, mitre, alexey, angel, berengar, sing,
# Nearest to most: some, all, myles, more, many, ragtime, relinquished, various,
# Nearest to four: three, eight, six, five, seven, two, nine, zero,
# Nearest to i: ii, you, we, they, vilhelm, noodles, expletive, tolerated,
# Nearest to to: would, not, will, iud, can, may, depository, nez,
# Nearest to of: original, valiantly, brahui, primitive, for, in, and, cretian,
# Nearest to also: which, sometimes, who, still, generally, that, not, traditionally,
# Nearest to his: their, her, its, the, aeon, my, this, posner,
# Nearest to can: may, would, will, should, could, must, cannot, to,
# Nearest to if: since, when, but, defenseless, centrepiece, sadd, leno, discontinue,
# Nearest to was: is, had, has, were, became, been, be, although,
# Nearest to after: before, during, when, hhs, at, merging, from, sampras,
# Average loss at step 22000: 3.501796
# Average loss at step 24000: 3.486957
# Average loss at step 26000: 3.484958
# Average loss at step 28000: 3.478352
# Average loss at step 30000: 3.503039
# Nearest to he: she, it, they, who, there, we, but, devaluation,
# Nearest to an: cryonicists, meticulously, southerly, crops, golgi, myrinet, huron, solidly,
# Nearest to other: many, some, these, various, different, such, are, regional,
# Nearest to zero: five, eight, seven, four, six, nine, three, two,
# Nearest to history: surgeries, salaam, breakers, list, ordinals, angel, isosceles, justice,
# Nearest to most: some, more, myles, many, use, ragtime, plurality, hutchins,
# Nearest to four: five, six, three, eight, seven, nine, two, zero,
# Nearest to i: ii, you, we, they, sectarian, noodles, iii, tolerated,
# Nearest to to: would, will, nez, criminalization, must, nrsv, can, iud,
# Nearest to of: in, including, lattimore, original, gladiators, politecnico, from, for,
# Nearest to also: it, sometimes, still, which, often, generally, learns, there,
# Nearest to his: her, their, its, the, s, my, aeon, macclesfield,
# Nearest to can: may, will, would, could, should, must, cannot, might,
# Nearest to if: when, since, but, where, centrepiece, is, while, though,
# Nearest to was: is, had, has, were, been, became, when, delaying,
# Nearest to after: before, during, when, from, until, at, hhs, convocation,
# Average loss at step 32000: 3.500073
# Average loss at step 34000: 3.491132
# Average loss at step 36000: 3.455501
# Average loss at step 38000: 3.301119
# Average loss at step 40000: 3.426172
# Nearest to he: she, it, they, who, there, we, eventually, i,
# Nearest to an: cartography, another, overdose, meticulously, cryonicists, huron, unaccented, polisario,
# Nearest to other: different, various, dean, these, many, hopkins, japonic, several,
# Nearest to zero: five, seven, nine, eight, six, three, four, two,
# Nearest to history: list, geography, surgeries, libby, directory, breakers, mitre, solutes,
# Nearest to most: more, some, many, totaling, use, convex, ragtime, among,
# Nearest to four: six, five, three, eight, seven, two, nine, one,
# Nearest to i: you, we, ii, they, he, delos, t, noodles,
# Nearest to to: will, would, deride, could, can, may, rowena, upholding,
# Nearest to of: in, brahui, original, cretian, including, from, janssen, and,
# Nearest to also: which, often, still, sometimes, usually, now, generally, typically,
# Nearest to his: their, her, its, my, your, the, s, aeon,
# Nearest to can: will, may, could, would, must, should, cannot, might,
# Nearest to if: when, where, since, but, centrepiece, sadd, rabba, is,
# Nearest to was: is, has, had, became, were, be, been, grothendieck,
# Nearest to after: before, during, when, falun, convocation, dianne, until, hhs,
# Average loss at step 42000: 3.434977
# Average loss at step 44000: 3.451867
# Average loss at step 46000: 3.451291
# Average loss at step 48000: 3.349661
# Average loss at step 50000: 3.386652
# Nearest to he: she, it, they, who, there, eventually, this, planted,
# Nearest to an: cartography, overdose, imre, southerly, cryonicists, another, juries, polisario,
# Nearest to other: various, different, many, definable, others, some, japonic, profit,
# Nearest to zero: seven, five, eight, six, four, nine, three, two,
# Nearest to history: list, syndicalist, surgeries, savages, geography, lynn, guillaume, consonances,
# Nearest to most: more, many, some, totaling, myles, use, among, ronaldo,
# Nearest to four: seven, eight, six, three, five, nine, two, zero,
# Nearest to i: we, ii, you, t, they, iii, expletive, mayo,
# Nearest to to: could, can, effendi, would, parlor, should, deride, depository,
# Nearest to of: in, valiantly, and, brahui, detonating, uganda, importation, undernet,
# Nearest to also: still, often, now, usually, which, sometimes, typically, generally,
# Nearest to his: their, her, its, my, your, macclesfield, him, the,
# Nearest to can: could, may, will, would, must, should, cannot, might,
# Nearest to if: when, where, since, while, although, though, after, but,
# Nearest to was: is, has, had, became, were, been, be, by,
# Nearest to after: before, during, when, while, if, dianne, until, upon,
# Average loss at step 52000: 3.439010
# Average loss at step 54000: 3.422971
# Average loss at step 56000: 3.438225
# Average loss at step 58000: 3.396874
# Average loss at step 60000: 3.389595
# Nearest to he: she, it, they, eventually, there, who, we, octavio,
# Nearest to an: overdose, cryonicists, heartbroken, golgi, nguni, cartography, polisario, osi,
# Nearest to other: different, various, many, definable, others, some, several, physical,
# Nearest to zero: five, four, eight, six, seven, nine, three, two,
# Nearest to history: demographics, list, geography, solutes, main, politics, economy, lynn,
# Nearest to most: some, many, more, use, ragtime, various, exams, totaling,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Nearest to i: ii, we, you, they, jure, she, not, he,
# Nearest to to: parlor, iud, paullus, myasthenia, sudetenland, might, nrsv, depository,
# Nearest to of: for, valiantly, in, haikai, same, sufism, including, summarizes,
# Nearest to also: still, now, often, sometimes, typically, usually, there, actually,
# Nearest to his: her, their, its, my, your, aeon, him, macclesfield,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to if: when, where, since, though, although, whether, before, then,
# Nearest to was: is, had, has, became, were, been, be, when,
# Nearest to after: before, during, when, while, despite, following, until, without,
# Average loss at step 62000: 3.241725
# Average loss at step 64000: 3.256150
# Average loss at step 66000: 3.403974
# Average loss at step 68000: 3.391501
# Average loss at step 70000: 3.362449
# Nearest to he: she, it, they, eventually, there, who, we, octavio,
# Nearest to an: cartography, the, overdose, cantos, juries, cryonicists, golgi, southerly,
# Nearest to other: various, different, many, others, japonic, some, such, biological,
# Nearest to zero: five, four, six, eight, seven, nine, three, two,
# Nearest to history: list, demographics, geography, solutes, bridgeport, syndicalist, consecrate, vdc,
# Nearest to most: more, many, some, exams, less, all, various, use,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to i: ii, we, you, nr, expletive, he, they, she,
# Nearest to to: can, must, would, will, iud, could, should, cannot,
# Nearest to of: including, and, valiantly, numeric, in, widdecombe, include, guelleh,
# Nearest to also: still, often, which, sometimes, now, actually, there, usually,
# Nearest to his: her, their, my, its, your, our, the, aeon,
# Nearest to can: may, could, will, would, should, must, cannot, might,
# Nearest to if: when, where, though, while, since, although, before, whether,
# Nearest to was: is, has, were, had, became, been, be, when,
# Nearest to after: before, during, when, while, despite, until, aleman, from,
# Average loss at step 72000: 3.372023
# Average loss at step 74000: 3.352606
# Average loss at step 76000: 3.311686
# Average loss at step 78000: 3.346816
# Average loss at step 80000: 3.380072
# Nearest to he: she, it, they, there, eventually, who, we, octavio,
# Nearest to an: shrunk, cryonicists, overdose, fleece, southerly, cartography, cantos, heartbroken,
# Nearest to other: various, others, many, different, some, japonic, profit, including,
# Nearest to zero: five, seven, six, eight, four, three, nine, two,
# Nearest to history: list, demographics, geography, consecrate, intrinsically, fingers, twenties, chickie,
# Nearest to most: some, more, many, exams, less, among, rationalism, all,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to i: ii, we, you, iii, jure, they, he, g,
# Nearest to to: must, would, will, should, iud, idealist, vse, rowena,
# Nearest to of: including, hacked, in, valiantly, biogeography, entire, janssen, livius,
# Nearest to also: still, now, often, sometimes, which, actually, usually, microclimates,
# Nearest to his: her, their, its, my, your, our, the, aeon,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to if: when, where, though, since, whether, although, before, wi,
# Nearest to was: is, became, were, had, has, been, becomes, being,
# Nearest to after: before, during, when, while, despite, upon, without, until,
# Average loss at step 82000: 3.404244
# Average loss at step 84000: 3.407427
# Average loss at step 86000: 3.386744
# Average loss at step 88000: 3.351109
# Average loss at step 90000: 3.363762
# Nearest to he: she, it, they, there, who, eventually, we, octavio,
# Nearest to an: shrunk, collation, cryonicists, another, polisario, overdose, nicknamed, golgi,
# Nearest to other: various, others, different, japonic, scenario, profit, ryukyu, many,
# Nearest to zero: five, seven, six, eight, four, nine, three, two,
# Nearest to history: list, demographics, geography, breakers, waltrip, period, contemporaneous, bai,
# Nearest to most: many, more, some, less, exams, among, rationalism, all,
# Nearest to four: six, eight, seven, three, five, two, nine, zero,
# Nearest to i: ii, you, we, iii, g, t, int, jure,
# Nearest to to: idealist, will, would, iud, effendi, must, deride, datura,
# Nearest to of: including, valiantly, for, in, include, abrogated, and, rayner,
# Nearest to also: still, now, often, which, actually, sometimes, typically, usually,
# Nearest to his: her, their, its, my, your, our, the, s,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to if: when, where, since, though, whether, before, wi, until,
# Nearest to was: is, became, had, were, has, be, been, becomes,
# Nearest to after: before, during, when, while, despite, until, without, upon,
# Average loss at step 92000: 3.399742
# Average loss at step 94000: 3.250926
# Average loss at step 96000: 3.362412
# Average loss at step 98000: 3.242228
# Average loss at step 100000: 3.357541
# Nearest to he: she, it, they, there, who, we, eventually, octavio,
# Nearest to an: another, cantos, overdose, shrunk, collation, cartography, nguni, meticulously,
# Nearest to other: others, various, including, different, japonic, scenario, themselves, many,
# Nearest to zero: four, five, eight, seven, six, nine, three, two,
# Nearest to history: list, demographics, geography, bangladeshi, main, bridgeport, academic, vdc,
# Nearest to most: more, less, many, among, exams, some, lodi, holocene,
# Nearest to four: six, seven, five, eight, three, two, nine, zero,
# Nearest to i: ii, you, we, expletive, they, iii, hemiparesis, jure,
# Nearest to to: will, could, can, must, should, would, may, iud,
# Nearest to of: including, in, original, from, hacked, primed, rehnquist, during,
# Nearest to also: still, now, actually, sometimes, often, never, typically, usually,
# Nearest to his: her, their, my, its, your, our, the, s,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to if: when, where, though, since, while, whether, wi, before,
# Nearest to was: is, became, has, had, were, been, becomes, when,
# Nearest to after: before, when, during, despite, without, while, upon, thus,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
    global data_index
    # skip window is the amount of words we're looking at from each side of a given word
    # creates a single batch
    span = 2 * skip_window + 1
    batch = np.ndarray(shape=(batch_size, span -1), dtype = np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # e.g if skip_window = 2 then span = 5
    # span is the length of the whole frame we are considering for a single word (left + word + right)
    # skip_window is the length of one side
    
    # queue which add and pop at the end
    buffer = collections.deque(maxlen=span)
    #get words starting from index 0 to span
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    # num_skips => # of times we select a random word within the span?
    for i in range(batch_size):
        target = skip_window
        targets_to_avoid = [skip_window]
        # add selected target to avoid_list for next time
        col_idx = 0
        for j in range(span):
            if (j == span//2):
                continue
            batch[i, col_idx] = buffer[j]
            col_idx +=1
        labels[i,0] = buffer[skip_window]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

data_index = 0
batch, labels = generate_batch(8, 2)

input = []
for bi in batch:
    tmp = []
    for index in bi:
        tmp.append(reverse_dictionary[index])
    input.append(tmp)

print('    batch:', input)
print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * skip_window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], 
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model
    embeds = None
    for i in range(2 * skip_window):
        embedding_i = tf.nn.embedding_lookup(embeddings, train_dataset[:, i])
        #print ("embedding %d of shape %s" % (i, embedding_i.get_shape().as_list()))
        emb_x,emb_y = embedding_i.get_shape().as_list()
        if (embeds is None):
            embeds = tf.reshape(embedding_i,[emb_x,emb_y,1])
        else:
            embeds = tf.concat(2,[embeds,tf.reshape(embedding_i,[emb_x,emb_y,1])])
        
    assert embeds.get_shape().as_list()[2]== 2*skip_window
    print ("Concat embedding size %s" %embeds.get_shape().as_list())
    avg_embeds = tf.reduce_mean(embeds, 2, keep_dims=False)
    print ("Average embedding size %s" %avg_embeds.get_shape().as_list())
    
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, avg_embeds, 
                                                     train_labels, num_sampled, vocabulary_size))
    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# Concat embedding size [128, 128, 2]
# Average embedding size [128, 128]

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.619266
# Nearest to and: tors, territory, harald, plant, kordofanian, outfitted, tiu, hausdorff,
# Nearest to between: rgensen, listening, dumplings, kernels, stretches, dma, decomposers, ethnically,
# Nearest to will: xm, insurmountable, functors, urls, sampa, silesian, guises, mcgovern,
# Nearest to state: christine, bomarc, tack, monoids, sulphur, anaxagoras, phenol, relena,
# Nearest to by: bakkers, alkmaar, overdrive, ineffable, befriends, geocities, settling, ere,
# Nearest to system: purported, dewitt, dissension, flugelhorn, promenade, romney, inputs, akihito,
# Nearest to but: frankenchrist, mjw, psp, psycho, usurpers, lycos, marbury, tangent,
# Nearest to states: quarrel, maclean, airtight, automobile, therapy, attributes, thither, toe,
# Nearest to during: cures, hamburg, trudeau, charge, ermine, bog, crept, benthic,
# Nearest to than: expressing, longbows, penetrating, pueblo, whitfield, launch, landless, hamid,
# Nearest to also: functions, pid, paramount, sponsoring, boyz, aviators, idealized, languedoc,
# Nearest to these: entrances, rump, advocate, pied, gilman, manuals, midwives, batsman,
# Nearest to at: annoy, uninterrupted, racquets, nieve, transformer, toto, coursing, constantine,
# Nearest to history: penicillin, infections, doomed, leaps, cleese, irenaeus, garner, vr,
# Nearest to only: pectoral, steam, functional, universalist, departed, linnean, milgram, protagonists,
# Nearest to have: emotionally, reception, injunction, accumulate, resurrecting, irt, marquette, popularised,
# Average loss at step 2000: 4.034811
# Average loss at step 4000: 3.510234
# Average loss at step 6000: 3.341458
# Average loss at step 8000: 3.192916
# Average loss at step 10000: 3.146609
# Nearest to and: or, microprocessor, proxima, fullback, but, american, pesticides, which,
# Nearest to between: with, brassiere, listening, playfair, cosmologists, hydrate, commodores, pulaski,
# Nearest to will: would, can, could, must, may, urls, xm, should,
# Nearest to state: sulphur, flour, ga, bomarc, rtiges, relena, icelandic, tack,
# Nearest to by: through, overdrive, spectrometry, thant, implicate, administer, deductive, internet,
# Nearest to system: purported, dewitt, romney, flugelhorn, inputs, exothermic, caveat, persecute,
# Nearest to but: mjw, francois, frankenchrist, however, wreckin, cadmium, and, dirham,
# Nearest to states: maclean, airtight, automobile, therapy, attributes, dog, essays, absalom,
# Nearest to during: waiver, trudeau, thematic, against, in, mohel, retaining, after,
# Nearest to than: expressing, hamid, wreckin, launch, pueblo, keynes, longbows, double,
# Nearest to also: transmitted, often, infanta, not, functions, who, euroscepticism, uneven,
# Nearest to these: advocate, rump, some, passport, medical, entrances, framers, albedo,
# Nearest to at: in, near, iata, on, abscess, hengest, transformer, ucla,
# Nearest to history: roo, elven, penicillin, cleese, vr, secam, excuses, vampire,
# Nearest to only: pectoral, inflection, milos, protagonists, steam, functional, milgram, universalist,
# Nearest to have: had, has, be, were, stitched, define, ibelin, are,
# Average loss at step 12000: 3.169682
# Average loss at step 14000: 3.127345
# Average loss at step 16000: 3.150146
# Average loss at step 18000: 3.100057
# Average loss at step 20000: 2.995474
# Nearest to and: or, but, postmodernists, charleston, quranic, own, including, proxima,
# Nearest to between: with, brassiere, mould, kohen, listening, cosmologists, commodores, inc,
# Nearest to will: would, can, could, may, must, should, cannot, harpsichordist,
# Nearest to state: relena, sulphur, bomarc, phenol, inositol, flour, qed, customization,
# Nearest to by: overdrive, alkmaar, deductive, through, uploading, implicate, administer, getty,
# Nearest to system: purported, kaohsiung, exothermic, beast, cluny, marsh, confident, caveat,
# Nearest to but: and, however, chivalrous, francois, mjw, allowed, although, trintignant,
# Nearest to states: maclean, countries, automobile, attributes, therapy, essays, airtight, biking,
# Nearest to during: waiver, in, against, after, retaining, trudeau, mesa, cures,
# Nearest to than: or, expressing, wreckin, double, hamid, conformations, keynes, ppm,
# Nearest to also: now, often, transmitted, still, never, not, infanta, euroscepticism,
# Nearest to these: some, such, many, mp, gell, carlton, upstate, medical,
# Nearest to at: near, in, on, iata, transformer, hengest, coursing, supports,
# Nearest to history: meddle, vampire, excuses, vr, itinerant, elven, college, installations,
# Nearest to only: pectoral, protagonists, definition, milos, universalist, inflection, overlay, still,
# Nearest to have: had, has, were, are, be, include, stitched, according,
# Average loss at step 22000: 3.052388
# Average loss at step 24000: 3.024096
# Average loss at step 26000: 2.990356
# Average loss at step 28000: 3.015354
# Average loss at step 30000: 2.989810
# Nearest to and: or, but, exhibit, own, barre, including, unintentionally, hausdorff,
# Nearest to between: with, brassiere, mould, kohen, inc, listening, commodores, lonsdaleite,
# Nearest to will: would, can, could, may, must, should, cannot, might,
# Nearest to state: relena, hemoglobin, icelandic, bomarc, kinase, flour, sulphur, qed,
# Nearest to by: overdrive, through, deductive, achaea, getty, administer, quaternion, affricates,
# Nearest to system: beast, kaohsiung, systems, purported, jeffersonian, confident, program, exothermic,
# Nearest to but: however, and, deanna, lud, chivalrous, francois, sulfuric, trintignant,
# Nearest to states: maclean, countries, attributes, kingdom, automobile, essays, championships, tuesday,
# Nearest to during: in, after, against, under, waiver, at, cond, retaining,
# Nearest to than: or, expressing, ppm, and, thermonuclear, safest, conformations, longbows,
# Nearest to also: now, often, still, never, transmitted, which, actually, widely,
# Nearest to these: some, such, many, various, friz, carlton, both, gell,
# Nearest to at: near, in, iata, hengest, during, transformer, on, etruscans,
# Nearest to history: itinerant, meddle, vampire, vr, ennio, installations, ejaculation, excitement,
# Nearest to only: pectoral, still, definition, therefore, overlay, milos, universalist, protagonists,
# Nearest to have: had, has, were, are, include, be, stitched, infante,
# Average loss at step 32000: 2.844084
# Average loss at step 34000: 2.946248
# Average loss at step 36000: 2.939151
# Average loss at step 38000: 2.939665
# Average loss at step 40000: 2.922278
# Nearest to and: or, but, quranic, while, postmodernists, including, than, own,
# Nearest to between: with, brassiere, mould, among, inc, kohen, listening, commodores,
# Nearest to will: would, can, could, may, must, should, cannot, might,
# Nearest to state: qed, mormon, supersede, kinase, flour, icelandic, maximizing, relena,
# Nearest to by: through, overdrive, getty, deductive, achaea, alkmaar, during, towards,
# Nearest to system: systems, program, beast, jeffersonian, persecute, kaohsiung, purported, confident,
# Nearest to but: however, and, sulfuric, chivalrous, deanna, francois, lud, trintignant,
# Nearest to states: countries, maclean, kingdom, attributes, genre, athens, babcock, essays,
# Nearest to during: in, after, against, waiver, from, under, cond, through,
# Nearest to than: or, and, ppm, much, safest, thermonuclear, expressing, wreckin,
# Nearest to also: still, now, often, never, which, actually, usually, shea,
# Nearest to these: such, some, those, various, many, both, gell, which,
# Nearest to at: near, transformer, hengest, in, iata, gein, guderian, hopping,
# Nearest to history: mainland, itinerant, vampire, meddle, fanatic, kuril, classical, vr,
# Nearest to only: overlay, pectoral, therefore, alamanni, definition, still, just, impossible,
# Nearest to have: had, has, were, are, include, having, be, infante,
# Average loss at step 42000: 2.941829
# Average loss at step 44000: 2.944836
# Average loss at step 46000: 2.903521
# Average loss at step 48000: 2.866984
# Average loss at step 50000: 2.845986
# Nearest to and: or, but, while, proxima, barzani, habsburgs, motilal, including,
# Nearest to between: with, brassiere, mould, among, kohen, inc, listening, commodores,
# Nearest to will: would, can, could, may, must, should, cannot, might,
# Nearest to state: qed, kinase, supersede, icelandic, mormon, scrupulously, inositol, relena,
# Nearest to by: through, getty, republicanism, administer, towards, deductive, marquee, during,
# Nearest to system: systems, program, kaohsiung, jeffersonian, beast, purported, confident, persecute,
# Nearest to but: however, and, chivalrous, although, though, which, lud, while,
# Nearest to states: countries, us, maclean, kingdom, attributes, athens, genre, babcock,
# Nearest to during: in, after, against, under, waiver, from, cond, through,
# Nearest to than: or, ppm, longbows, much, safest, expressing, use, hier,
# Nearest to also: now, still, often, actually, never, usually, which, always,
# Nearest to these: such, some, various, several, those, many, both, gell,
# Nearest to at: near, transformer, in, hengest, during, iata, apocrypha, on,
# Nearest to history: mainland, itinerant, vr, sl, kuril, fanatic, preferential, meddle,
# Nearest to only: therefore, overlay, never, just, still, even, pectoral, definition,
# Nearest to have: had, has, were, are, include, having, stitched, schodt,
# Average loss at step 52000: 2.883651
# Average loss at step 54000: 2.861902
# Average loss at step 56000: 2.859154
# Average loss at step 58000: 2.765785
# Average loss at step 60000: 2.829453
# Nearest to and: or, but, although, quranic, including, while, habsburgs, unintentionally,
# Nearest to between: with, among, brassiere, mould, within, kohen, assuming, usemodwiki,
# Nearest to will: would, can, could, may, must, should, cannot, might,
# Nearest to state: qed, maximizing, inositol, scrupulously, icelandic, mormon, sportsman, relena,
# Nearest to by: through, during, marquee, alkmaar, deductive, enjoying, overdrive, getty,
# Nearest to system: systems, program, kaohsiung, jeffersonian, expertise, confident, method, purported,
# Nearest to but: however, and, although, which, see, allowed, chivalrous, mindanao,
# Nearest to states: countries, kingdom, us, maclean, genre, athens, attributes, nations,
# Nearest to during: in, after, under, when, through, at, against, within,
# Nearest to than: or, ppm, lives, thermonuclear, much, diagnosing, longbows, safest,
# Nearest to also: still, now, often, actually, usually, never, always, currently,
# Nearest to these: several, such, those, many, some, various, which, both,
# Nearest to at: near, in, during, hengest, iata, on, transformer, guderian,
# Nearest to history: mainland, vr, itinerant, strasbourg, kuril, exchanger, meddle, excitement,
# Nearest to only: just, overlay, alamanni, never, therefore, still, simply, always,
# Nearest to have: had, has, were, are, having, include, be, previously,
# Average loss at step 62000: 2.834620
# Average loss at step 64000: 2.775973
# Average loss at step 66000: 2.766843
# Average loss at step 68000: 2.721449
# Average loss at step 70000: 2.777654
# Nearest to and: or, but, while, habsburgs, although, charleston, however, quranic,
# Nearest to between: with, among, brassiere, within, mould, kohen, inc, usemodwiki,
# Nearest to will: would, can, could, must, may, should, cannot, might,
# Nearest to state: qed, sportsman, states, kinase, mormon, inositol, scrupulously, vorder,
# Nearest to by: through, during, getty, newly, alkmaar, leaflet, deductive, uploading,
# Nearest to system: systems, program, kaohsiung, process, model, expertise, confident, method,
# Nearest to but: however, although, and, mindanao, though, see, spokes, which,
# Nearest to states: kingdom, us, countries, athens, genre, nations, maclean, babcock,
# Nearest to during: in, after, under, through, throughout, when, from, at,
# Nearest to than: or, arras, ppm, longbows, thermonuclear, much, diagnosing, safest,
# Nearest to also: now, still, often, actually, never, always, which, currently,
# Nearest to these: those, several, such, some, various, many, numerous, both,
# Nearest to at: near, in, hengest, transformer, during, toad, guderian, iata,
# Nearest to history: mainland, itinerant, fanatic, strasbourg, meddle, bishop, vr, demyelinating,
# Nearest to only: overlay, therefore, just, always, even, exactly, definition, alamanni,
# Nearest to have: had, has, are, were, include, having, be, contain,
# Average loss at step 72000: 2.803415
# Average loss at step 74000: 2.656091
# Average loss at step 76000: 2.802928
# Average loss at step 78000: 2.824664
# Average loss at step 80000: 2.785757
# Nearest to and: or, but, including, although, barzani, however, habsburgs, armageddon,
# Nearest to between: among, with, brassiere, mould, within, kohen, usemodwiki, inc,
# Nearest to will: would, can, could, must, should, may, cannot, might,
# Nearest to state: qed, apollodorus, states, kyrgyz, sportsman, caters, maximizing, inositol,
# Nearest to by: during, through, marquee, getty, without, towards, against, administer,
# Nearest to system: systems, program, expertise, kaohsiung, jeffersonian, process, persecute, method,
# Nearest to but: however, although, and, though, which, gorman, mindanao, chivalrous,
# Nearest to states: countries, kingdom, us, nations, athens, attributes, films, maclean,
# Nearest to during: in, after, under, through, when, throughout, before, at,
# Nearest to than: or, much, arras, diagnosing, longbows, ppm, thermonuclear, safest,
# Nearest to also: now, still, often, never, actually, always, currently, usually,
# Nearest to these: those, several, some, such, many, various, both, they,
# Nearest to at: near, in, during, hengest, guderian, toad, transformer, ucla,
# Nearest to history: mainland, strasbourg, itinerant, vr, fanatic, appalachians, kuril, demographics,
# Nearest to only: overlay, always, just, therefore, alamanni, memex, even, definition,
# Nearest to have: had, has, were, are, include, having, receive, contain,
# Average loss at step 82000: 2.674714
# Average loss at step 84000: 2.774566
# Average loss at step 86000: 2.739484
# Average loss at step 88000: 2.752329
# Average loss at step 90000: 2.739564
# Nearest to and: or, including, but, although, quranic, craven, postmodernists, proxima,
# Nearest to between: among, with, within, brassiere, mould, kohen, coincident, listening,
# Nearest to will: would, can, could, must, should, may, cannot, might,
# Nearest to state: qed, apollodorus, inositol, emilio, press, sportsman, republic, reserve,
# Nearest to by: through, towards, deductive, marquee, alkmaar, enjoying, newly, getty,
# Nearest to system: systems, program, kaohsiung, expertise, process, confident, model, equitable,
# Nearest to but: however, although, though, and, which, see, chivalrous, until,
# Nearest to states: countries, kingdom, us, nations, athens, maclean, attributes, genre,
# Nearest to during: in, after, under, throughout, before, through, when, within,
# Nearest to than: or, arras, longbows, much, diagnosing, tok, safest, ppm,
# Nearest to also: now, still, often, never, actually, always, sparsely, currently,
# Nearest to these: those, such, some, several, various, many, multiple, numerous,
# Nearest to at: near, in, during, hengest, iata, guderian, toad, manzarek,
# Nearest to history: mainland, strasbourg, fanatic, list, appalachians, demographics, teaching, deportation,
# Nearest to only: just, always, alamanni, overlay, therefore, exactly, easily, simply,
# Nearest to have: had, has, were, are, include, having, contain, receive,
# Average loss at step 92000: 2.691859
# Average loss at step 94000: 2.728428
# Average loss at step 96000: 2.710282
# Average loss at step 98000: 2.375164
# Average loss at step 100000: 2.420606
# Nearest to and: or, but, including, however, sportspeople, barre, habsburgs, who,
# Nearest to between: among, with, within, mould, brassiere, sarai, kohen, coincident,
# Nearest to will: would, can, could, should, must, cannot, may, might,
# Nearest to state: qed, states, caters, inositol, republic, apollodorus, reserve, government,
# Nearest to by: through, without, towards, when, marquee, cliffordadams, during, retarded,
# Nearest to system: systems, program, expertise, kaohsiung, confident, jeffersonian, process, method,
# Nearest to but: however, although, though, and, which, until, mindanao, sadc,
# Nearest to states: kingdom, us, countries, nations, athens, state, genre, attributes,
# Nearest to during: in, after, at, under, despite, throughout, before, when,
# Nearest to than: or, arras, much, diagnosing, ppm, considerably, tok, magnified,
# Nearest to also: still, now, often, never, actually, always, currently, which,
# Nearest to these: those, such, several, some, multiple, many, various, certain,
# Nearest to at: near, in, during, guderian, toad, tolvaj, on, woolen,
# Nearest to history: mainland, strasbourg, list, tradition, appalachians, teaching, demyelinating, demographics,
# Nearest to only: overlay, alamanni, just, especial, always, jackals, therefore, exactly,
# Nearest to have: had, has, are, were, include, having, contain, require,
